# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# Спасибо, что поправил, удачи в следующих спринтах ✌
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью твоей работы. Давай будем общаться на «ты».
#
# У тебя хорошая, внимательная работа 👍 Но кое-что надо поправить: в основном надо убрать замену пропусков там, где она некорректна и стоит сделать так, чтобы у каждого графика было название. В остальном всё здорво, можно посмотреть комментарии и задать вопросы, если есть :)
#
#
# Зелёным цветом отмечены комментарии, формально не требующие правки, но правки приветствуются. Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому или можно поправить прямо сейчас.
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее». Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.номер итерации`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div class="alert alert-info" style="background:pink;color:#A91E69">
# <h2>Комментарий студента </h2>
#     ...
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#-Комментарий-ревьюера" data-toc-modified-id="-Комментарий-ревьюера-2"><span class="toc-item-num">2&nbsp;&nbsp;</span> Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента-" data-toc-modified-id="Комментарий-студента--4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Комментарий студента </a></span></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Коммнтарий-ревьюера" data-toc-modified-id="Коммнтарий-ревьюера-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Коммнтарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера" data-toc-modified-id="Коммнтарий-ревьюера-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Коммнтарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера" data-toc-modified-id="Коммнтарий-ревьюера-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Коммнтарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-27"><span class="toc-item-num">27&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-28"><span class="toc-item-num">28&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-29"><span class="toc-item-num">29&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-30"><span class="toc-item-num">30&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-31"><span class="toc-item-num">31&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-32"><span class="toc-item-num">32&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-33"><span class="toc-item-num">33&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-34"><span class="toc-item-num">34&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Коммнтарий-ревьюера-V.2" data-toc-modified-id="Коммнтарий-ревьюера-V.2-35"><span class="toc-item-num">35&nbsp;&nbsp;</span>Коммнтарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-36"><span class="toc-item-num">36&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-37"><span class="toc-item-num">37&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-38"><span class="toc-item-num">38&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-39"><span class="toc-item-num">39&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-40"><span class="toc-item-num">40&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-41"><span class="toc-item-num">41&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-42"><span class="toc-item-num">42&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-43"><span class="toc-item-num">43&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-44"><span class="toc-item-num">44&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
data_house=pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

display(data_house.head(5))


data_house.info()


data_house.columns
#display(data.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Если вывод данных делать, то когд писать в разных блоках, речь об этом?:)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# Не, о том, чтобы в одной ячейке между логическими блоками были пробелы, чтобы убоднее было читать
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера</h2>
#
# Вокруг `=` лучше ставить пробелы и отделять логически блоки новыми строками друг от друга
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Данные в исходном файле файле были разделены символом горизотального пробела (Tab), для этого в значении sep мы использовали '\t'.
# 2. В таблице 23699 строк и 22 столбца
# 3. Все наименования столбцов написаны латинскими, строчными буквами. Замена не нужна
# 4. Пропуски данных имеются в следующих столбцах
# - ceiling_height          14504
# - floors_total            23613
# - living_area             21796
# - is_apartment            2775 (замена на bool)
# - kitchen_area            21421
# - balcony                 12180
# - locality_name           23650
# - airports_nearest        18157
# - cityCenters_nearest     18180
# - parks_around3000        18181
# - parks_nearest           8079
# - ponds_around3000        18181
# - ponds_nearest           9110
# - days_exposition         20518
# 5. Типы данных, которые присутствуют в таблице
#     dtypes: bool(2), float64(14), int64(3), object(3)

# %% [markdown]
# ## Предобработка данных

# %%
# Выведем количество пропусков в процентном соотношении
data_house.isna().mean().reset_index()
# Out:
#                    index         0
# 0           total_images  0.000000
# 1             last_price  0.000000
# 2             total_area  0.000000
# 3   first_day_exposition  0.000000
# 4                  rooms  0.000000
# 5         ceiling_height  0.387991
# 6           floors_total  0.003629
# 7            living_area  0.080299
# 8                  floor  0.000000
# 9           is_apartment  0.882906
# 10                studio  0.000000
# 11             open_plan  0.000000
# 12          kitchen_area  0.096122
# 13               balcony  0.486054
# 14         locality_name  0.002068
# 15      airports_nearest  0.233850
# 16   cityCenters_nearest  0.232879
# 17      parks_around3000  0.232837
# 18         parks_nearest  0.659100
# 19      ponds_around3000  0.232837
# 20         ponds_nearest  0.615596
# 21       days_exposition  0.134225

# %%
# Удалим повторяющиеся значения в столбце locality_name
data_house.dropna(subset=['locality_name'], inplace = True)
data_house['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Закомментировал замену "Высота потолков" и "количество этажей":)
# </div>

# %%
# Заменим в столбце ceiling_height высоту потолков на медианные значения
#median_ceiling_height = data_house['ceiling_height'].median()
#data_house['ceiling_height'].fillna(median_ceiling_height, inplace = True)
#data_house['ceiling_height'].isna().sum()

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера</h2>
#
# Высота потолков зависит от типа постройки, которую мы определить не можем, поэтому возможно стоит оставить пропуски. Ниже аналогично, странно заменять этаж в доме на медианный
# </div>

# %%
# Заменим в столбце floors_total количество этажей на медианное значение
#median_floors_total = data_house['floors_total'].median()
#data_house['floors_total'].fillna(median_floors_total, inplace = True)
#data_house['floors_total'] = data_house['floors_total'].astype('int')
#data_house['floors_total'].isna().sum()
#data_house.info()

# %%
# Для замены  пропусков в living_area создадим новый столбец p_1m2
data_house['p_1m2'] = data_house['last_price']/data_house['living_area']
data_house.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    balcony    locality_name  airports_nearest  cityCenters_nearest  \
# ...

# %%
# группируем по району для замены пропусков
grouped_price=data_house.groupby('locality_name')['p_1m2'].transform('median')
# Заполняем пропуски медианным значением стоимости 1 м.кв в зависимости от района
data_house['p_1m2'].fillna(grouped_price,inplace=True)

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Возьму на вооружение данный метод, спасибо.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера</h2>
#
# Интересная идея 👍 Можно было таким же образом и с кухней поступить. Ещё можно сгруппировать по площади и числу комнат и посчитать соотношение `living_area / total_area` по группам и таким образом на среднее заменить. Это не самый очевидный `groupby`, поэтому делюсь,
#
# ```python
#
# gb = df.groupby(['total_area','rooms'])
# df['living_area'] = df['living_area'].fillna(gb['living_area'].transform(lambda group: group.mean() / (group.name[0])) * df['total_area'])
#
# ```
#
# </div>

# %%
# Заменим пропуски в столбце p_1m2
data_house['p_1m2'].fillna(grouped_price, inplace = True)
data_house['p_1m2'].isna().sum()
# Out:
# 17

# %%
# удалим пропуски nan в p_1m2'
data_house.dropna(subset = ['p_1m2'], inplace = True)
data_house['p_1m2'].isna().sum()
# Out:
# 0

# %%
# Заменим значения в столбце living_area
data_house['living_area'].isna().sum()
# Out:
# 1881

# %%
# Заменим пропуски в столбце living_area разделив стоимость квартиры на цену 1 кв.м
data_house['living_area'].fillna(data_house['last_price']/data_house['p_1m2'], inplace = True)
data_house['living_area'].isna().sum()
# Out:
# 0

# %%
# Заменим пропуски в столбце is_apartament
data_house['is_apartment'] = data_house['is_apartment'].astype('bool') 
data_house['is_apartment'].fillna(0)
data_house['is_apartment'].isna().sum()
# Out:
# 0

# %%
# Заменим пропуски в столбце kitchen_area
median_kitchen_area = data_house['kitchen_area'].median()
data_house['kitchen_area'].fillna(median_kitchen_area, inplace = True)
data_house['kitchen_area'].isna().sum()
# Out:
# 0

# %%
# Заменим пропуски в столбце balcony. Если балкон не указан, значит его нет
data_house['balcony'] = data_house['balcony'].fillna(0)
data_house['balcony'] = data_house['balcony'].astype('int')
data_house['balcony'].isna().sum()
# Out:
# 0

# %%
# Заменим пропуски в столбце airports_nearest
data_house['airports_nearest'] = data_house['airports_nearest'].astype('float64')
grouped_airpots_nearest = data_house.groupby('locality_name')['airports_nearest'].transform('mean')
data_house['airports_nearest'].fillna(grouped_airpots_nearest,inplace=True)
data_house['airports_nearest'].isna().sum()
# Out:
# 5371

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Как в данной ситуации правильнее рассуждать при замене данных или создании категорий, а потом замене на среднее значение?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# Не понимаю вопрос :) https://loginom.ru/blog/missing здесь неплохой материал про замену данных, а для географических столбцов нужно 2 ориентира (как в прямоугольных координатах), чтобы корректно можно было группировать
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Такая замена такого числа пропусков очень сильно в итоге смещает оценки, более того, географические данные попросту таким способ заменить тяжело (хотя если бы у нас было хотя бы расстояние до двух точек, то можно было)
# </div>

# %%
# Где остались пропуски расстояния до аэропорта  заполняем просто по среднемму значению расстояния
#data_house['airports_nearest']=data_house['airports_nearest'].fillna(data_house['airports_nearest'].median())
#data_house['airports_nearest'].isna().sum()

# %%
# Заменим пропуски в столбце cityCenters_nearest
#data_house['cityCenters_nearest'] = data_house['cityCenters_nearest'].astype('float64')
#grouped_cityCenters_nearest = data_house.groupby('cityCenters_nearest')['cityCenters_nearest'].transform('mean')
#data_house['cityCenters_nearest'].fillna(grouped_airpots_nearest,inplace=True)
#data_house['cityCenters_nearest'].isna().sum()

# %%
# Где остались пропуски расстояния до аэропорта  заполняем просто по среднемму значению расстояния
#data_house['cityCenters_nearest'] = data_house['cityCenters_nearest'].fillna(data_house['cityCenters_nearest'].median())
#data_house['cityCenters_nearest'].isna().sum()

# %%
# Заменим пропуски в столбце parks_around3000
#median_parks_around3000 = data_house['parks_around3000'].median()
#data_house['parks_around3000'].fillna(median_parks_around3000, inplace = True)
#data_house['parks_around3000'] = data_house['parks_around3000'].astype('int')
#data_house['parks_around3000'].isna().sum()

# %%
# Заменим пропуски в столбце parks_nearest
#median_parks_nearest = data_house['parks_nearest'].median()
#data_house['parks_nearest'].fillna(median_parks_nearest, inplace = True)
#data_house['parks_nearest'] = data_house['parks_nearest'].astype('int')
#data_house['parks_nearest'].isna().sum()

# %%
# Заменим пропуски в столбце ponds_around3000
#median_ponds_around3000 = data_house['ponds_around3000'].median()
#data_house['ponds_around3000'].fillna(median_ponds_around3000, inplace = True)
#data_house['ponds_around3000'] = data_house['ponds_around3000'].astype('int')
#data_house['ponds_around3000'].isna().sum()

# %%
# Заменим пропуски в столбце ponds_around3000
#median_ponds_nearest = data_house['ponds_nearest'].median()
#data_house['ponds_nearest'].fillna(median_ponds_nearest, inplace = True)
#data_house['ponds_nearest'] = data_house['ponds_nearest'].astype('int')
#data_house['ponds_nearest'].isna().sum()

# %%
# Заменим пропуски в столбце ponds_around3000
#median_days_exposition = data_house['days_exposition'].median()
#data_house['days_exposition'].fillna(median_days_exposition, inplace = True)
#data_house['days_exposition'] = data_house['days_exposition'].astype('int')
#data_house['days_exposition'].isna().sum()

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера</h2>
#
# Ну очевидно, что квартиры с пропусками ещё не проданы и висят в актуальных объявлениях. В этом можно убедиться, посмотрев на распределение их `firt_day_expostion`. Такая замены в итоге приводит к неправильным выводам ниже
# </div>

# %%
# Заменим пропуски в столбце parks_around3000
data_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23633 entries, 0 to 23698
# Data columns (total 23 columns):
# total_images            23633 non-null int64
# last_price              23633 non-null float64
# total_area              23633 non-null float64
# first_day_exposition    23633 non-null object
# rooms                   23633 non-null int64
# ceiling_height          14486 non-null float64
# floors_total            23548 non-null float64
# living_area             23633 non-null float64
# floor                   23633 non-null int64
# is_apartment            23633 non-null bool
# studio                  23633 non-null bool
# open_plan               23633 non-null bool
# kitchen_area            23633 non-null float64
# balcony                 23633 non-null int64
# locality_name           23633 non-null object
# airports_nearest        18262 non-null float64
# cityCenters_nearest     18137 non-null float64
# parks_around3000        18138 non-null float64
# ...

# %% [markdown]
# # Вывод

# %% [markdown]
# Пропуски заполнены.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Почему бы просто пропуски не оставить там, где не поулчается корректно заменить?
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# Создадим функцию категоризации этажей и добавим новый столбец с категориями
def floor_cat (row):
    floor_1 = row['floor']
    floor_last = row['floors_total']
    if  floor_1 == 1:
        return 'Первый'
    if floor_1 == floor_last:
        return 'Последний'
    return 'Другой'

# %%
# Создадим функцию категоризации этажей и добавим новый столбец с категориями
data_house['floor_cat'] = data_house.apply(floor_cat, axis = 1)
data_house.head(2)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.7          16.0         51.0      8          True  ...
# 1             NaN          11.0         18.6      1          True  ...
#
#      locality_name  airports_nearest  cityCenters_nearest  parks_around3000  \
# 0  Санкт-Петербург           18863.0              16028.0               1.0
# 1   посёлок Шушары           12817.0              18603.0               0.0
#
#   parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 0         482.0               2.0          755.0              NaN
# 1           NaN               0.0            NaN             81.0
#
#            p_1m2  floor_cat
# 0  254901.960784     Другой
# 1  180107.526882     Первый
#
# ...

# %%
# Переведем столбец first_day_exposition в формат даты, чтобы найти неделю, месяц и год публикации
data_house['first_day_exposition'] = pd.to_datetime(data_house['first_day_exposition'],format='%Y.%m.%dT%H:%M:%S').dt.round('1D')
# Создадим столбцы неделя/месяц/год
data_house['day_number'] = data_house['first_day_exposition'].dt.weekday
data_house['month'] = data_house['first_day_exposition'].dt.month
data_house['year'] = data_house['first_day_exposition'].dt.year
data_house.head(2)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.7          16.0         51.0      8          True  ...
# 1             NaN          11.0         18.6      1          True  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0               1.0          482.0               2.0          755.0
# 1               0.0            NaN               0.0            NaN
#
#   days_exposition          p_1m2  floor_cat  day_number  month  year
# 0             NaN  254901.960784     Другой           3      3  2019
# 1            81.0  180107.526882     Первый           1     12  2018
#
# [2 rows x 27 columns]

# %%
# Найдем отношение жилой площади к общей и отношение площади кухни к общей площади квартиры
data_house['living_area_to_total_area'] = data_house['living_area']/data_house['total_area']*100
data_house['kitchen_area_to_total_area'] = data_house['kitchen_area']/data_house['total_area']*100
data_house.head(2)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.7          16.0         51.0      8          True  ...
# 1             NaN          11.0         18.6      1          True  ...
#
#    ponds_around3000  ponds_nearest  days_exposition          p_1m2 floor_cat  \
# 0               2.0          755.0              NaN  254901.960784    Другой
# 1               0.0            NaN             81.0  180107.526882    Первый
#
#    day_number  month  year  living_area_to_total_area  \
# 0           3      3  2019                  47.222222
# 1           1     12  2018                  46.039604
#
#    kitchen_area_to_total_area
# 0                   23.148148
# 1                   27.227723
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# Импортируем библиотеку для построения графиков, выведем общую информацию о площади
data_house['total_area'].describe()
# Out:
# count    23633.000000
# mean        60.330999
# std         35.654245
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.750000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Все импорты лучше иметь в начале работы, чтобы сразу были понятны нужые зависимости
# </div>

# %%
# Анализируем диапазоны площадей квартир
data_house.plot(kind = 'hist', y = 'total_area', grid = True, range = (12, 200),title = 'Площадь квартиры',figsize = (7,5) )

# %% [markdown]
# <div class="alert alert-info">
#
# Больше всего квартир в диапазоне от 30 до 50 кв. м
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Все графики лучше подписывать
# </div>

# %%
# Выведем общую информацию о цене
data_house['last_price'].describe()
# Out:
# count    2.363300e+04
# mean     6.544222e+06
# std      1.089952e+07
# min      1.219000e+04
# 25%      3.413000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
# Анализируем ценовые диапазоны квартир
data_house.plot(kind = 'hist', y = 'last_price', grid = True, bins = 8, title = 'Стоимость квартиры', range = (1000000, 8000000), figsize = (7,5))

# %% [markdown]
# <div class="alert alert-info">
#
# Больше всего квартир в диапазоне от 2,9 до 5,5 млн. руб.
#
# </div>

# %%
# Выведем общую информацию о количестве комнат в квартире
data_house['rooms'].describe()
# Out:
# count    23633.000000
# mean         2.070114
# std          1.078598
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
# Анализируем количество комнат в продаваемых квартирах
data_house.plot(kind = 'hist', y = 'rooms', bins = 10, range = (0, 10), title = 'Количество комнат', grid = True, figsize = (7,5))

# %% [markdown]
# <div class="alert alert-info">
#
# Больше всего продаются 1 и 2-ух комнатные квартиры
#
# </div>

# %%
# Выведем общую информацию о высоте потолков
data_house['ceiling_height'].describe()
# Out:
# count    14486.000000
# mean         2.771355
# std          1.261760
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
# Анализируем количество компнат в продаваемых квартирах
data_house.plot(kind = 'hist', y = 'ceiling_height', bins = 100,title = 'Высота потолка', range = (2.6, 3), grid = True, figsize = (7,5))

# %% [markdown]
# <div class="alert alert-info">
#
# Больше всего продаются квартир с высотой потолка 2.6 и 2.7 м
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Оставил данные без замены, результат изменился существенно
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# Вообще на самом деле замену делать можно, но для этого надо исследовать от чего зависит высота потолков, поэтому проще оставить, ещё т.к. высота потолков величина по факту дискретная, то вместо гистограммы можно строить барчарт на `value_counts`
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Такой огромный пик из-за замены на медиану
# </div>

# %% [markdown]
# # Время продажи квартиры
# 1.Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
#
# - Применим метод describe к столбцу days_exposition и построим диаграмму рассеяния методом boxplot
# - Отбросим выбросы, если они имеются и построим по полученному срезу гистограмму

# %%
data_house['days_exposition'].describe()
# Out:
# count    20455.000000
# mean       180.771938
# std        219.740889
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data_house.boxplot(column = 'days_exposition')

# %% [markdown]
# Отбросим выбросы, находящиеся за пределами Q3 + 1.5 * IQR = 510. Построим срез методом query

# %%
import matplotlib.ticker as ticker
query_days_exposition = data_house.query('days_exposition < 510')
query_days_exposition['days_exposition'].describe()
#query_days_exposition.xaxis.set_major_locator(ticker.MultipleLocator(50))
# Out:
# count    18776.000000
# mean       128.304857
# std        120.987828
# min          1.000000
# 25%         41.000000
# 50%         85.000000
# 75%        182.000000
# max        509.000000
# Name: days_exposition, dtype: float64

# %%
query_days_exposition['days_exposition'].value_counts()
# Out:
# 45.0     872
# 60.0     538
# 7.0      234
# 30.0     208
# 90.0     203
#         ...
# 2.0        3
# 486.0      3
# 373.0      3
# 508.0      3
# 1.0        1
# Name: days_exposition, Length: 509, dtype: int64

# %%
x_values = [0,50,100,150,200,250,300,350,400,450]
# query_days_exposition.plot(kind = 'hist', xticks = x_values,  y = 'days_exposition',title = 'Дней показов объявления', bins = 100, grid = True, figsize = (15, 5))
query_days_exposition.plot(kind = 'hist', xticks= range(0,460,50),  y = 'days_exposition',title = 'Дней показов объявления', bins = 100, grid = True, figsize = (15, 5))
#plt.xticks(x_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-741abf5e130b> in <module>
#       1 x_values = [0,50,100,150,200,250,300,350,400,450]
#       2 # query_days_exposition.plot(kind = 'hist', xticks = x_values,  y = 'days_exposition',title = 'Дней показов объявления', bins = 100, grid = True, figsize = (15, 5))
# ----> 3 query_days_exposition.plot(kind = 'hist', xticks= range(0,460,50),  y = 'days_exposition',title = 'Дней показов объявления', bins = 100, grid = True, figsize = (15, 5))
#       4 #plt.xticks(x_values)
#
# NameError: name 'query_days_exposition' is not defined

# %% [markdown]
# <div class="alert alert-info">
#
# Вывод:
#     Больше всего квартир продается на 45 день после размещения объявления.
#     Также есть всплески на 60 день после размещения объявления.
#     Быстрой можно считать продажу квартиры, если после размещения объявления и продажи прошло меньше 7 дней.
#     Долгой можно считать ту продажу, если с момента размещения объявления и продажей прошло больше 180 дней.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Ругается на range(0,460,50), говорит что у него 2 аргумента
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# `range()` это генератор, т.е. надо `xticks=range(0,450,50)`
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Эти всплески это выбросы, а 95 из-за того, что ты медианой заполнил :) https://yandex.ru/support/realty/owner/home/add-ads-housing.html Такой `x_values` это `range(0,460,50)`
# </div>

# %% [markdown]
# Проверим на аномальные выбросы следующие столбцы last_price, p_1m2 , % living_area to total_area, % kitchen_area to total_area

# %%
name = ['last_price','p_1m2','living_area_to_total_area','kitchen_area_to_total_area']
for row in name:
    query_days_exposition.plot(kind = 'hist', y = row, bins = 100, title = row, figsize = (10,5))

# %% [markdown]
# На гистограммах видно следующее:
# - last_price большее количество квартир лежит в диапазоне до 5-7 млн. Есть выбросы в район 80 млн, так как размерная сетка выстраивается автоматически,
# - p_1m2 здесь наблюдается такая же картина, общая стоимость 1 кв. метра находится в максимальном пределе до 250 тыс за кв. метр
# - living_area to total_area - по логике жилая площадь должна быть меньше общей, однако есть выбросы, где это наоборот. Так как мы анализируем среднестатистические квартиры, то первым делаем мы сделам срез, чтобы отношение жилой площади к общей не превышало 100%
#
#
# Сделаем срез по living_area_to_total_area< 100 & last_price < 15 000 000 & p_1m2 < 700 000 и посмотрим на полученные гистрограммы

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера</h2>
#
# Ну `p_1m2` это всё таки цена за кв. метр для всей площади, а не только для `living_area`
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Немного не понял, какие здесь нужно изменения внести по p_1m2
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# Делить `last_price` на `total_area`, а не на `living_area`
# </div>

# %%
query_data_house = query_days_exposition.query('living_area_to_total_area< 100 & last_price < 15000000 & p_1m2 < 700000')
for row in name:
    query_data_house.plot(kind = 'hist', y = row,title = row, bins = 100, figsize = (7,5))

# %%
# Выведем потери в процентном соотношение относительно последней чистки данных
potery=100-len(query_data_house)/len(query_days_exposition)*100
potery
# Out:
# 4.005112910097992

# %% [markdown]
# <div class="alert alert-info">
#
# Вывод:
#     Удалось убрать редкие и выделяющиеся значения в столбцах living_area_to_total_area, last_price, p_1m2 с потерей данных в 5%
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍 Удаление выбросов позволяет корректнее расчитывать корреляцию http://www.machinelearning.ru/wiki/index.php?title=%D0%9A%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82_%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D0%B8_%D0%9F%D0%B8%D1%80%D1%81%D0%BE%D0%BD%D0%B0 здесь можно увидеть картинку, которая показывает, как может повлиять выброс
# </div>

# %% [markdown]
# Зависимость стоимости квартиры от площади, этажа, удаленности

# %%
# Создадим сводную таблицу по locality_name
data_pivot_1 = query_data_house.pivot_table(index = 'locality_name', values = ['last_price', 'total_area','rooms','cityCenters_nearest','floor'], aggfunc = 'median')
display(data_pivot_1.corr())
graph=pd.plotting.scatter_matrix(data_pivot_1, figsize=(20, 9))
# Out:
#                      cityCenters_nearest     floor  last_price     rooms  \
# cityCenters_nearest             1.000000 -0.412444   -0.010281  0.358217
# floor                          -0.412444  1.000000    0.270869 -0.151694
# last_price                     -0.010281  0.270869    1.000000  0.112537
# rooms                           0.358217 -0.151694    0.112537  1.000000
# total_area                      0.082389 -0.035991    0.472340  0.715331
#
#                      total_area
# cityCenters_nearest    0.082389
# floor                 -0.035991
# last_price             0.472340
# rooms                  0.715331
# total_area             1.000000

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Для вывода датафреймов лучше пользоваться `display`, а чтобы не выводилась куча из `array[axes]` можно обернуть последнее выражение в присваивание `_ = pd.plotting..` Ещё на таком масштабе конечно тяжело что-то разглядеть :)
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Подкорректировал график и вывод
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммнтарий ревьюера V.2</h2>
#
# 👍
# </div>

# %%
data_pivot_2 = query_data_house.groupby('floor_cat')['last_price'].median()
data_pivot_2.plot(kind = 'bar', x = 'floor_cat',title = 'floor_cat', y = 'last_price')

# %% [markdown]
# Интерпретация значений коэффициента корреляции
# Значение	Интерпретация
# - до 0,2	Очень слабая
# - до 0,5	Слабая
# - до 0,7	Средняя
# - до 0,9	Высокая
# - свыше 0,9	Очень высокая корреляция

# %% [markdown]
# <div class="alert alert-info">
#
# - Влияние количества комнат на цену - есть положительная коррелящия, однака зависимость не сильная (0.11)
# - Влияние удаленности квартиры от центра на цену - есть отрицательная коррелящия, цена падает при отдолении от центра (-0,01)
# - Влияние площади на цену квартиры - самая высокая положительная коррелящия. Чем больше площадь, тем выше стоимость квартиры (0,47)
# - Влияние этажа на стоимость квартиры - имеет положительная корреляция, она ниже корреляции цены по площади. Люди предпочитаю жить выше, поэтому спрос на такие квартиры больше. (0,27)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
#
# Странно, что чем дальше от центра, тем дороже. Возможно не стоило заменять 5к строк медианой :)
# </div>

# %% [markdown]
# Зависимость количества объявлений от даты размещения

# %%
date = ['day_number','month', 'year']
for row in date:
    data_pivot_3 = query_data_house.groupby(row)['last_price'].count()
    data_pivot_3.plot(style = '-o', x = row, title = row,figsize = (7,5))
    plt.show()

# %% [markdown]
# <div class="alert alert-info">
#
# - Большей всего объявлений размещают в будние дни
# - Активный рост размещения объявлений начинается с конца мая и начало июня. Рост продолжается до начала зимы. В период с декабря по февраль наблюдается спад и пикового значение достигается в начале февраля после праздников и падает в период майских праздников
# - Активный рост количества объявлений начался с 2015 года и достиг пика в 2018. Далее количество объявлений пошло на спад
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# - Вопрос ревьюеру???? Как потом locality_name сделать столбцом, чтобы можно было делать срезы
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# После `pivot`? Можно сделать `reset_index()`
# </div>

# %%
data_pivot_4 = query_data_house.pivot_table(index='locality_name', values = 'p_1m2', aggfunc=('count','median'))
data_pivot_4.sort_values(by='count',ascending=False).head(10).plot(style = '-o', y = 'median', figsize = (20,5))

# %% [markdown]
# <div class="alert alert-info">
#
# - Самая низкая стоимость квадратного метра в Выборге
# - Самая высокая стоимость квадратного метра в поселке Парголово
#
# </div>

# %% [markdown]
# Изучим стоимость жилья СПБ от удаленности до центра

# %%
# Создадим столбец расстояния до центра в км
query_data_house['cityCenters_nearest_km'] = query_data_house['cityCenters_nearest']/1000
#data_house['cityCenters_nearest_km'] = data_house['cityCenters_nearest_km'].fillna(0)
#query_data_house['cityCenters_nearest_km'] = query_data_house['cityCenters_nearest_km'].astype('int')
query_data_house['cost_of_km']=query_data_house['last_price']/query_data_house['cityCenters_nearest_km']
pd.set_option('chained_assignment',None)
query_data_house.head(5)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0       40.40           2018-12-04      1
# 4             2  10000000.0      100.00           2018-06-19      2
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Чтобы не было таких предупреждений, можно сделать как просят в нём и переписать на `.loc`, а если не поможет, то можно сделать `pd.set_option('chained_assignment',None)`
#
# </div>

# %%
# Создадим срез по СПБ
spb_query_data_house = query_data_house.query('locality_name =="Санкт-Петербург"').reset_index(drop =True)
spb_query_data_house.sort_values(by='cityCenters_nearest_km',ascending=True).plot(x='cityCenters_nearest_km',y='cost_of_km', style='o',alpha=0.3,figsize=(20,10))

# %% [markdown]
# <div class="alert alert-info">
#
# - Примерно после 5 км стоимость начинает меняться незначительно. Поэтому будем считать данный радиус центром
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍
# </div>

# %% [markdown]
# Проанализируем квартиры в центре СПБ

# %%
# Создадим срез по центру СПБ
centr_SPB= query_data_house.query('locality_name =="Санкт-Петербург" and cityCenters_nearest_km <= 5').reset_index(drop =True)
metric = ['last_price','total_area', 'rooms', 'ceiling_height']
for row in metric:
    centr_SPB.plot(kind = 'hist', y = row, bins = 100, title = row, grid = True, figsize = (20,10))
    plt.show()

# %% [markdown]
# <div class="alert alert-info">
#
# - Большей всего квартир в центр со стоимостью порядка 7 млн. руб
# - Есть 2 пика по площади в районе 40 м. кв и в районе 60 м. кв
# - Преобладающее количество комнат 2
# - Высота потолков находится в районе 2.6 - 2.7 метров
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Чтобы лучше увидеть разницу, тут можно как ты ниже сделал друг на друга нанести две гистограммы, одну для центра, другую для всего остального. Переменные кстати с большой буквы не принято начинать, так обычно классы называют
# </div>

# %% [markdown]
# Проанализируем квартиры в центре СПБ и все квартиры в СПБ

# %%
# Создадим срез по центру СПБ
metric_2 = ['rooms', 'ceiling_height','floor_cat', 'cityCenters_nearest','day_number','month', 'year']
for row in metric_2:
    centr_SPB.groupby(row)['last_price'].median().plot(x= row,y='last_price',style='o-',grid=True,figsize=(10,5),legend=True)
    spb_query_data_house.groupby(row)['last_price'].median().plot(x= row,y='last_price',style='o-',grid=True,figsize=(20,8),legend=True)
    plt.show()

# %% [markdown]
# <div class="alert alert-info">
#
# - На графиках видно, что поведение при выборе квартир в центр СПБ и во всем СПБ идентичны. Единственное различие в том, что в центр квартиры более дорогие
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут конечно лучше скатерплоты в паре мест :)
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Согласно проведенной исследовательской работе, можно сделать вывод, что больше всего квартир продается в будние дни, самые неактивные месяцы продаж - это новогодние и майские праздники. Самыми популярными квартирами являются 2-ух комнатные квартиры с площадью от 45 - 60 м. кв. Стоимость квартиры имеет положительную корреляцию по любом, кроме первого этажа, с высотой потолка 2,6-2,7 м за цену около 4,5 млн. руб. Цена квартиры зависет от этажа, района, близости к центру, от высоты потолка и от кол-ва комнат в ней.
# Так же мы выяснили, что квартиры чаще всего продаются на 45-ый день после размещения объявления. Быстрой же продажей можно считать ту, которая состоялась в течение 1 месяца (30 дней)

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
